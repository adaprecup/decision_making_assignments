# %% [markdown]
# #  Multi-Objective Evolutionary Optimization: Final Assignment
#
# ## Overview
#
# In this notebook, we apply many-objective evolutionary optimization to explore **non-dominated policy sets** for dike reinforcement and spatial interventions within the Overijssel region. Our aim is to identify robust strategies that balance the interests of multiple stakeholders while respecting specific physical and institutional constraints.
#
# ## Scope of the Analysis
#
# - **Focus region**: The optimization is focused on two dike rings:
#   - **Deventer** (`A.4`)
#   - **Grossel** (`A.5`)
#
# - **Constraints applied**:
#   - **Dike height increase** for both Deventer and Grossel is constrained between **5 and 10 dm**.
#   - **Room for the River (RfR) projects** are **activated** only for those of strategic interest to **Rijkswaterstaat (RWS)**:
#     - Dike rings: `A.1` (Doesburg), `A.3` (Zupthen), and `A.4` (Grossel)
#
# - **Decision space**:
#   - We search over **policy levers**, which include dike reinforcements and RfR implementations.
#   - All other interventions are treated as optional and will be explored by the algorithm.
#
# - **Evaluation criteria**:
#   - Objectives reflect the priorities of the **Province of Overijssel**, such as minimizing flood risk and economic damages, while preserving social and ecological outcomes.
#
# ## Purpose
#
# This analysis uses the `optimize()` functionality from the `ema_workbench`, relying on an $\epsilon$-NSGAII algorithm to:
# - Discover a set of **Pareto-optimal policies** under complex trade-offs.
# - Support negotiation and coordination between regional actors (e.g., RWS, local municipalities, and the province).
# - Identify **robust** strategies that perform well under a wide range of uncertain future scenarios.
#
# ## Key Features
#
# - Integration of **realistic policy constraints** from stakeholders.
# - Use of $\epsilon$-archiving and **parallel coordinate plots** to visualize trade-offs.
# - Inclusion of **convergence metrics** and optional seed analysis to assess solution quality.

# %%
import pandas as pd
import networkx as nx
import os
import copy
import numpy as np
from ema_workbench.examples.sd_boostedtrees_flu import experiments, outcomes
from fontTools.misc.bezierTools import epsilon

# Ensure archive directory exists
archive_dir = "./archives"
os.makedirs(archive_dir, exist_ok=True)
# Out:
# /Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/__init__.py:101: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn("ipyparallel not installed - IpyparalleEvaluator not available")
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       4 import copy
#       5 import numpy as np
# ----> 6 from ema_workbench.examples.sd_boostedtrees_flu import experiments, outcomes
#       7 from fontTools.misc.bezierTools import epsilon
#       9 # Ensure archive directory exists
#
# File ~/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/examples/sd_boostedtrees_flu.py:48
#      44         ax.hist(x[idx, x1], range=(x_min, x_max), alpha=0.5)
#      47 # load data
# ---> 48 experiments, outcomes = load_results("./data/1000 flu cases with policies.tar.gz")
#      50 # transform to numpy array with proper recoding of cateogorical variables
#      51 x, columns = feature_scoring._prepare_experiments(experiments)
#
# File ~/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/utilities.py:46, in load_results(file_name)
#      42 from ..em_framework.outcomes import AbstractOutcome, register
#      44 file_name = os.path.abspath(file_name)
# ---> 46 with tarfile.open(file_name, "r:gz", encoding="UTF8") as archive:
#      47     try:
#      48         f = archive.extractfile("metadata.json")
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/tarfile.py:1878, in TarFile.open(cls, name, mode, fileobj, bufsize, **kwargs)
#    1876     else:
#    1877         raise CompressionError("unknown compression type %r" % comptype)
# -> 1878     return func(name, filemode, fileobj, **kwargs)
#    1880 elif "|" in mode:
#    1881     filemode, comptype = mode.split("|", 1)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/tarfile.py:1926, in TarFile.gzopen(cls, name, mode, fileobj, compresslevel, **kwargs)
#    1923     raise CompressionError("gzip module is not available") from None
#    1925 try:
# -> 1926     fileobj = GzipFile(name, mode + "b", compresslevel, fileobj)
#    1927 except OSError as e:
#    1928     if fileobj is not None and mode == 'r':
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/gzip.py:194, in GzipFile.__init__(self, filename, mode, compresslevel, fileobj, mtime)
#     192     mode += 'b'
#     193 if fileobj is None:
# --> 194     fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     195 if filename is None:
#     196     filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/precupada/decision_making_assignments/final assignment EPA141/model_scripts/data/1000 flu cases with policies.tar.gz'

# %%
# make sure pandas is version 1.0 or higher
# make sure networkx is verion 2.4 or higher
print(pd.__version__)
print(nx.__version__)
# Out:
# 2.2.3
# 3.4.2

# %%
from ema_workbench import (
    Policy,
    ema_logging,
    MultiprocessingEvaluator,
    save_results, 
    load_results,
    Samplers,
    IntegerParameter
)
from problem_formulation import get_model_for_problem_formulation

# %%
ema_logging.log_to_stderr(ema_logging.INFO)
# Out:
# <Logger EMA (DEBUG)>

# %% [markdown]
# ## Overview
#
# This notebook runs the optimization algorithm (ε-NSGAII) to generate a diverse set of non-dominated policy alternatives, and saves the resulting input–output data for further analysis.
#
# While the MOEA algorithm is executed here via the `optimize()` function, the full analysis of convergence behavior, stakeholder trade-offs, and Pareto front exploration is performed in a follow-up notebook.
# ### Key Elements
#
# - **Problem Formulation 3 (PF 3)** is used, which provides disaggregated scalar outcomes by dike ring, allowing policy evaluation at the regional level.
# - A custom function `MOEA_experiments(...)` is used to:
#   - Load the correct problem setup
#   - Apply constraints for stakeholder-specific preferences
#   - Run ε-NSGAII optimization using the EMA Workbench
#
# ### Policy Constraints
#
# The following policy constraints reflect both national and provincial stakeholder preferences:
#
# - **Room for the River projects** are turned ON for dike rings `A.1`, `A.3`, and `A.4` to represent the interests of **Rijkswaterstaat (RWS)**.
# - **Dike increases** for Deventer (`A.3`) and Grossel (`A.5`) are limited to **5–10 dm** to reflect preferences of the **Province of Overijssel**.
#
# ### Epsilon Configuration
#
# Instead of manually specifying ε-values, they are **automatically generated** based on the range of outcomes from prior exploratory analysis. This improves:
# - Adaptability to different problem formulations
# - Efficiency and interpretability of the Pareto front
#
# ### Output
#
# The optimization results and convergence logs are saved for further analysis, visualization, and stakeholder engagement.

# %%
def initialize_model(problem_formulation_id, active_rfr_dikes=None, constrained_dikes=None):
    from problem_formulation import get_model_for_problem_formulation
    dike_model, planning_steps = get_model_for_problem_formulation(problem_formulation_id)

    # Apply RfR forcing
    if active_rfr_dikes:
        new_levers = []
        for lev in dike_model.levers:
            if "RfR" in lev.name and any(dike in lev.name for dike in active_rfr_dikes):
                new_levers.append(IntegerParameter(lev.name, 1, 1))  # Force ON
            else:
                new_levers.append(lev)
        dike_model.levers = new_levers

    # Apply constraints on dike increases
    if constrained_dikes:
        new_levers = []
        for lev in dike_model.levers:
            replaced = False
            for dike, (low, high) in constrained_dikes.items():
                if dike in lev.name and "DikeIncrease" in lev.name:
                    new_levers.append(IntegerParameter(lev.name, low, high))
                    replaced = True
                    break
            if not replaced:
                new_levers.append(lev)
        dike_model.levers = new_levers

    return dike_model

# %%
def build_convergence_metrics(dike_model, archive_filename, enable_logging=True):
    from ema_workbench.em_framework.optimization import ArchiveLogger, EpsilonProgress
    metrics = [EpsilonProgress()]

    if enable_logging:
        archive_dir = "../experimental data"
        os.makedirs(archive_dir, exist_ok=True)
        logger = ArchiveLogger(
            archive_dir,
            [l.name for l in dike_model.levers],
            [o.name for o in dike_model.outcomes],
            base_filename=archive_filename
        )
        metrics.insert(0, logger)
    
    return metrics

# %%
def run_optimization(dike_model, nfe, epsilons, convergence_metrics):
    from ema_workbench import MultiprocessingEvaluator
    import time

    print(f"Starting optimization with {nfe} evaluations...")
    
    with MultiprocessingEvaluator(dike_model) as evaluator:
        results, convergence = evaluator.optimize(
            nfe=nfe,
            searchover="levers",
            epsilons=epsilons,
            convergence=convergence_metrics
        )
    
    print(f"Optimization completed.")
    return results, convergence

# %% [markdown]
# ## Optimization Configuration
#
# To run the MOEA effectively and efficiently, several key parameters were chosen based on best practices and the characteristics of the problem formulation:
#
# ### Number of Function Evaluations (`nfe = 20,000`)
# We use 20,000 function evaluations to allow the algorithm enough opportunity to explore the high-dimensional decision space and converge toward a diverse, high-quality Pareto front. Literature on many-objective optimization suggests 10k–50k evaluations as a practical range for balancing search depth and runtime.
#
# ### Epsilon Thresholds (`epsilons`)
# Instead of manually setting epsilon values, we compute them automatically as **5% of each outcome’s range**, based on results from a prior exploratory run. This:
# - Ensures outcome-specific granularity
# - Prevents overfitting to numerical noise
# - Produces a well-distributed and manageable set of non-dominated policies
#
# The formula used is:
#
# \[
# \varepsilon_i = 0.05 \times (\max_i - \min_i)
# \]
#
# for each outcome \(i\), where \(\max_i\) and \(\min_i\) are calculated from the exploratory `.tar.gz` archive.

# %%
def generate_epsilons_from_results(outcomes, fraction=0.05):
    """
    Generate epsilon values based on a fraction of the outcome range.

    Args:
        outcomes (dict): Dictionary of outcomes as returned by `load_results(...)`
        fraction (float): Fraction of the range to use for epsilon (e.g., 0.05 for 5%)

    Returns:
        List of epsilon values, in the order of outcomes.keys()
    """
    import numpy as np

    epsilons = []
    for name, values in outcomes.items():
        values = np.asarray(values)
        min_val, max_val = values.min(), values.max()
        range_val = max_val - min_val

        if range_val < 1e-5:
            epsilon = 1e-5  # avoid zero epsilon
        else:
            epsilon = range_val * fraction

        epsilons.append(epsilon)

    return epsilons

# %%
model = initialize_model(
    problem_formulation_id=3,
    active_rfr_dikes=["A.1", "A.3", "A.4"],
    constrained_dikes={"A.3": (5, 10), "A.5": (5, 10)}
)

# %%
convergence_metrics = build_convergence_metrics(model, ".tar.gz", enable_logging=False)
# Load exploratory results to compute epsilons
experiments_pf3, outcomes_pf3 = load_results("../experimental data/pf_3_exploratory_runs_levers_as_factors.tar.gz")
epsilon_pf3 = generate_epsilons_from_results(outcomes, fraction=0.05)
# Out:
# [MainProcess/INFO] results loaded successfully from /Users/precupada/decision_making_assignments/final assignment EPA141/experimental data/pf_3_exploratory_runs_levers_as_factors.tar.gz

# %%
results_moea, convergence = run_optimization(
    dike_model=model,
    nfe=200,
    epsilons=epsilon_pf3,  
    convergence_metrics=convergence_metrics
)
# Out:
# Starting optimization with 200 evaluations...
# /Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/__init__.py:101: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn("ipyparallel not installed - IpyparalleEvaluator not available")
# /Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/__init__.py:101: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn("ipyparallel not installed - IpyparalleEvaluator not available")
# /Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/__init__.py:101: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn("ipyparallel not installed - IpyparalleEvaluator not available")
# /Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/__init__.py:101: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn("ipyparallel not installed - IpyparalleEvaluator not available")
# /Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/__init__.py:101: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn("ipyparallel not installed - IpyparalleEvaluator not available")
# /Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/__init__.py:101: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn("ipyparallel not installed - IpyparalleEvaluator not available")
# /Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/__init__.py:101: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn("ipyparallel not installed - IpyparalleEvaluator not available")
# /Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/__init__.py:101: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn("ipyparallel not installed - IpyparalleEvaluator not available")
# [MainProcess/INFO] pool started with 8 workers
#   0%|                                                  | 0/200 [00:00<?, ?it/s]'ID flood wave shape'
# Traceback (most recent call last):
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 92, in run_experiment
#     model.run_model(scenario, policy)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 347, in run_model
#     outputs = self.run_experiment(experiment)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 400, in run_experiment
#     model_output = self.function(**experiment)
#   File "/Users/precupada/decision_making_assignments/final assignment EPA141/model_scripts/dike_model_function.py", line 180, in __call__
#     waveshape_id = node["ID flood wave shape"]
#                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'ID flood wave shape'
# Process SpawnPoolWorker-2:
# 'ID flood wave shape'
# Traceback (most recent call last):
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 92, in run_experiment
#     model.run_model(scenario, policy)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 347, in run_model
#     outputs = self.run_experiment(experiment)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 400, in run_experiment
#     model_output = self.function(**experiment)
#   File "/Users/precupada/decision_making_assignments/final assignment EPA141/model_scripts/dike_model_function.py", line 180, in __call__
#     waveshape_id = node["ID flood wave shape"]
#                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'ID flood wave shape'
# Process SpawnPoolWorker-6:
# 'ID flood wave shape'
# Traceback (most recent call last):
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 92, in run_experiment
#     model.run_model(scenario, policy)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 347, in run_model
#     outputs = self.run_experiment(experiment)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 400, in run_experiment
#     model_output = self.function(**experiment)
#   File "/Users/precupada/decision_making_assignments/final assignment EPA141/model_scripts/dike_model_function.py", line 180, in __call__
#     waveshape_id = node["ID flood wave shape"]
#                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'ID flood wave shape'
# Process SpawnPoolWorker-4:
# 'ID flood wave shape'
# Traceback (most recent call last):
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 92, in run_experiment
#     model.run_model(scenario, policy)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 347, in run_model
#     outputs = self.run_experiment(experiment)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 400, in run_experiment
#     model_output = self.function(**experiment)
#   File "/Users/precupada/decision_making_assignments/final assignment EPA141/model_scripts/dike_model_function.py", line 180, in __call__
#     waveshape_id = node["ID flood wave shape"]
#                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'ID flood wave shape'
# Process SpawnPoolWorker-7:
# 'ID flood wave shape'
# Traceback (most recent call last):
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 92, in run_experiment
#     model.run_model(scenario, policy)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 347, in run_model
#     outputs = self.run_experiment(experiment)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 400, in run_experiment
#     model_output = self.function(**experiment)
#   File "/Users/precupada/decision_making_assignments/final assignment EPA141/model_scripts/dike_model_function.py", line 180, in __call__
#     waveshape_id = node["ID flood wave shape"]
#                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'ID flood wave shape'
# Process SpawnPoolWorker-3:
# Traceback (most recent call last):
# 'ID flood wave shape'
# Traceback (most recent call last):
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 92, in run_experiment
#     model.run_model(scenario, policy)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 347, in run_model
#     outputs = self.run_experiment(experiment)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 400, in run_experiment
#     model_output = self.function(**experiment)
#   File "/Users/precupada/decision_making_assignments/final assignment EPA141/model_scripts/dike_model_function.py", line 180, in __call__
#     waveshape_id = node["ID flood wave shape"]
#                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'ID flood wave shape'
# Process SpawnPoolWorker-8:
# 'ID flood wave shape'
# Traceback (most recent call last):
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 92, in run_experiment
#     model.run_model(scenario, policy)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 347, in run_model
#     outputs = self.run_experiment(experiment)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 400, in run_experiment
#     model_output = self.function(**experiment)
#   File "/Users/precupada/decision_making_assignments/final assignment EPA141/model_scripts/dike_model_function.py", line 180, in __call__
#     waveshape_id = node["ID flood wave shape"]
#                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'ID flood wave shape'
# Process SpawnPoolWorker-1:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 92, in run_experiment
#     model.run_model(scenario, policy)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 347, in run_model
#     outputs = self.run_experiment(experiment)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 400, in run_experiment
#     model_output = self.function(**experiment)
#   File "/Users/precupada/decision_making_assignments/final assignment EPA141/model_scripts/dike_model_function.py", line 180, in __call__
#     waveshape_id = node["ID flood wave shape"]
#                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'ID flood wave shape'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 92, in run_experiment
#     model.run_model(scenario, policy)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 347, in run_model
#     outputs = self.run_experiment(experiment)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 400, in run_experiment
#     model_output = self.function(**experiment)
#   File "/Users/precupada/decision_making_assignments/final assignment EPA141/model_scripts/dike_model_function.py", line 180, in __call__
#     waveshape_id = node["ID flood wave shape"]
#                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'ID flood wave shape'
# Traceback (most recent call last):
# 'ID flood wave shape'
# Traceback (most recent call last):
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 92, in run_experiment
#     model.run_model(scenario, policy)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 347, in run_model
#     outputs = self.run_experiment(experiment)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 400, in run_experiment
#     model_output = self.function(**experiment)
#   File "/Users/precupada/decision_making_assignments/final assignment EPA141/model_scripts/dike_model_function.py", line 180, in __call__
#     waveshape_id = node["ID flood wave shape"]
#                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'ID flood wave shape'
#
# During handling of the above exception, another exception occurred:
#
# Process SpawnPoolWorker-5:
# Traceback (most recent call last):
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 92, in run_experiment
#     model.run_model(scenario, policy)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 347, in run_model
#     outputs = self.run_experiment(experiment)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 400, in run_experiment
#     model_output = self.function(**experiment)
#   File "/Users/precupada/decision_making_assignments/final assignment EPA141/model_scripts/dike_model_function.py", line 180, in __call__
#     waveshape_id = node["ID flood wave shape"]
#                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'ID flood wave shape'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/futures_multiprocessing.py", line 107, in worker
#     return experiment, experiment_runner.run_experiment(experiment)
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 108, in run_experiment
#     raise EMAError(f"Exception in run_model\nCaused by: {errortype}: {str(e)}")
# ema_workbench.util.ema_exceptions.EMAError: Exception in run_model
# Caused by: KeyError: 'ID flood wave shape'
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/futures_multiprocessing.py", line 107, in worker
#     return experiment, experiment_runner.run_experiment(experiment)
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 108, in run_experiment
#     raise EMAError(f"Exception in run_model\nCaused by: {errortype}: {str(e)}")
# ema_workbench.util.ema_exceptions.EMAError: Exception in run_model
# Caused by: KeyError: 'ID flood wave shape'
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/futures_multiprocessing.py", line 107, in worker
#     return experiment, experiment_runner.run_experiment(experiment)
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 108, in run_experiment
#     raise EMAError(f"Exception in run_model\nCaused by: {errortype}: {str(e)}")
# ema_workbench.util.ema_exceptions.EMAError: Exception in run_model
# Caused by: KeyError: 'ID flood wave shape'
# Traceback (most recent call last):
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 92, in run_experiment
#     model.run_model(scenario, policy)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 347, in run_model
#     outputs = self.run_experiment(experiment)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 400, in run_experiment
#     model_output = self.function(**experiment)
#   File "/Users/precupada/decision_making_assignments/final assignment EPA141/model_scripts/dike_model_function.py", line 180, in __call__
#     waveshape_id = node["ID flood wave shape"]
#                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'ID flood wave shape'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/futures_multiprocessing.py", line 107, in worker
#     return experiment, experiment_runner.run_experiment(experiment)
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 108, in run_experiment
#     raise EMAError(f"Exception in run_model\nCaused by: {errortype}: {str(e)}")
# ema_workbench.util.ema_exceptions.EMAError: Exception in run_model
# Caused by: KeyError: 'ID flood wave shape'
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 92, in run_experiment
#     model.run_model(scenario, policy)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 347, in run_model
#     outputs = self.run_experiment(experiment)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 400, in run_experiment
#     model_output = self.function(**experiment)
#   File "/Users/precupada/decision_making_assignments/final assignment EPA141/model_scripts/dike_model_function.py", line 180, in __call__
#     waveshape_id = node["ID flood wave shape"]
#                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'ID flood wave shape'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/futures_multiprocessing.py", line 107, in worker
#     return experiment, experiment_runner.run_experiment(experiment)
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 108, in run_experiment
#     raise EMAError(f"Exception in run_model\nCaused by: {errortype}: {str(e)}")
# ema_workbench.util.ema_exceptions.EMAError: Exception in run_model
# Caused by: KeyError: 'ID flood wave shape'
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 92, in run_experiment
#     model.run_model(scenario, policy)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 347, in run_model
#     outputs = self.run_experiment(experiment)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 400, in run_experiment
#     model_output = self.function(**experiment)
#   File "/Users/precupada/decision_making_assignments/final assignment EPA141/model_scripts/dike_model_function.py", line 180, in __call__
#     waveshape_id = node["ID flood wave shape"]
#                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'ID flood wave shape'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/futures_multiprocessing.py", line 107, in worker
#     return experiment, experiment_runner.run_experiment(experiment)
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 108, in run_experiment
#     raise EMAError(f"Exception in run_model\nCaused by: {errortype}: {str(e)}")
# ema_workbench.util.ema_exceptions.EMAError: Exception in run_model
# Caused by: KeyError: 'ID flood wave shape'
# Traceback (most recent call last):
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 92, in run_experiment
#     model.run_model(scenario, policy)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 347, in run_model
#     outputs = self.run_experiment(experiment)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 400, in run_experiment
#     model_output = self.function(**experiment)
#   File "/Users/precupada/decision_making_assignments/final assignment EPA141/model_scripts/dike_model_function.py", line 180, in __call__
#     waveshape_id = node["ID flood wave shape"]
#                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'ID flood wave shape'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 92, in run_experiment
#     model.run_model(scenario, policy)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 347, in run_model
#     outputs = self.run_experiment(experiment)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 400, in run_experiment
#     model_output = self.function(**experiment)
#   File "/Users/precupada/decision_making_assignments/final assignment EPA141/model_scripts/dike_model_function.py", line 180, in __call__
#     waveshape_id = node["ID flood wave shape"]
#                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'ID flood wave shape'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/futures_multiprocessing.py", line 107, in worker
#     return experiment, experiment_runner.run_experiment(experiment)
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 108, in run_experiment
#     raise EMAError(f"Exception in run_model\nCaused by: {errortype}: {str(e)}")
# ema_workbench.util.ema_exceptions.EMAError: Exception in run_model
# Caused by: KeyError: 'ID flood wave shape'
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/futures_multiprocessing.py", line 107, in worker
#     return experiment, experiment_runner.run_experiment(experiment)
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 108, in run_experiment
#     raise EMAError(f"Exception in run_model\nCaused by: {errortype}: {str(e)}")
# ema_workbench.util.ema_exceptions.EMAError: Exception in run_model
# Caused by: KeyError: 'ID flood wave shape'
# /Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/__init__.py:101: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn("ipyparallel not installed - IpyparalleEvaluator not available")
# 'ID flood wave shape'
# Traceback (most recent call last):
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 92, in run_experiment
#     model.run_model(scenario, policy)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 347, in run_model
#     outputs = self.run_experiment(experiment)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 400, in run_experiment
#     model_output = self.function(**experiment)
#   File "/Users/precupada/decision_making_assignments/final assignment EPA141/model_scripts/dike_model_function.py", line 180, in __call__
#     waveshape_id = node["ID flood wave shape"]
#                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'ID flood wave shape'
# Process SpawnPoolWorker-9:
# Traceback (most recent call last):
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 92, in run_experiment
#     model.run_model(scenario, policy)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 347, in run_model
#     outputs = self.run_experiment(experiment)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 400, in run_experiment
#     model_output = self.function(**experiment)
#   File "/Users/precupada/decision_making_assignments/final assignment EPA141/model_scripts/dike_model_function.py", line 180, in __call__
#     waveshape_id = node["ID flood wave shape"]
#                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'ID flood wave shape'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/futures_multiprocessing.py", line 107, in worker
#     return experiment, experiment_runner.run_experiment(experiment)
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 108, in run_experiment
#     raise EMAError(f"Exception in run_model\nCaused by: {errortype}: {str(e)}")
# ema_workbench.util.ema_exceptions.EMAError: Exception in run_model
# Caused by: KeyError: 'ID flood wave shape'
# /Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/__init__.py:101: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn("ipyparallel not installed - IpyparalleEvaluator not available")
# 'ID flood wave shape'
# Traceback (most recent call last):
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 92, in run_experiment
#     model.run_model(scenario, policy)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 347, in run_model
#     outputs = self.run_experiment(experiment)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 400, in run_experiment
#     model_output = self.function(**experiment)
#   File "/Users/precupada/decision_making_assignments/final assignment EPA141/model_scripts/dike_model_function.py", line 180, in __call__
#     waveshape_id = node["ID flood wave shape"]
#                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'ID flood wave shape'
# Process SpawnPoolWorker-10:
# Traceback (most recent call last):
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 92, in run_experiment
#     model.run_model(scenario, policy)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 347, in run_model
#     outputs = self.run_experiment(experiment)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 400, in run_experiment
#     model_output = self.function(**experiment)
#   File "/Users/precupada/decision_making_assignments/final assignment EPA141/model_scripts/dike_model_function.py", line 180, in __call__
#     waveshape_id = node["ID flood wave shape"]
#                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'ID flood wave shape'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/futures_multiprocessing.py", line 107, in worker
#     return experiment, experiment_runner.run_experiment(experiment)
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 108, in run_experiment
#     raise EMAError(f"Exception in run_model\nCaused by: {errortype}: {str(e)}")
# ema_workbench.util.ema_exceptions.EMAError: Exception in run_model
# Caused by: KeyError: 'ID flood wave shape'
# /Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/__init__.py:101: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn("ipyparallel not installed - IpyparalleEvaluator not available")
# 'ID flood wave shape'
# Traceback (most recent call last):
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 92, in run_experiment
#     model.run_model(scenario, policy)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 347, in run_model
#     outputs = self.run_experiment(experiment)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 400, in run_experiment
#     model_output = self.function(**experiment)
#   File "/Users/precupada/decision_making_assignments/final assignment EPA141/model_scripts/dike_model_function.py", line 180, in __call__
#     waveshape_id = node["ID flood wave shape"]
#                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'ID flood wave shape'
# Process SpawnPoolWorker-11:
# Traceback (most recent call last):
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/experiment_runner.py", line 92, in run_experiment
#     model.run_model(scenario, policy)
#     ~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 347, in run_model
#     outputs = self.run_experiment(experiment)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/util/ema_logging.py", line 153, in wrapper
#     res = func(*args, **kwargs)
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/model.py", line 400, in run_experiment
#     model_output = self.function(**experiment)
#   File "/Users/precupada/decision_making_assignments/final assignment EPA141/model_scripts/dike_model_function.py", line 180, in __call__
#     waveshape_id = node["ID flood wave shape"]
#                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'ID flood wave shape'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ~~~~^^^^^^^^^^^^^^^
#   File "/Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/futures_multiprocessing.py", line 107, in worker
# ...
#   warnings.warn("ipyparallel not installed - IpyparalleEvaluator not available")
# /Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/__init__.py:101: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn("ipyparallel not installed - IpyparalleEvaluator not available")
# /Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/__init__.py:101: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn("ipyparallel not installed - IpyparalleEvaluator not available")
# /Users/precupada/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/__init__.py:101: UserWarning: ipyparallel not installed - IpyparalleEvaluator not available
#   warnings.warn("ipyparallel not installed - IpyparalleEvaluator not available")
# Process SpawnPoolWorker-47:
# Process SpawnPoolWorker-48:
# Process SpawnPoolWorker-46:
# [MainProcess/INFO] terminating pool
# Process SpawnPoolWorker-50:
# Process SpawnPoolWorker-44:
# Process SpawnPoolWorker-43:
# Process SpawnPoolWorker-45:
# Process SpawnPoolWorker-49:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/queues.py", line 385, in get
#     res = self._reader.recv_bytes()
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 313, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/queues.py", line 384, in get
#     with self._rlock:
#          ^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#            ~~~~~~~~~~~~~~~~~~~~~~~^^
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 results_moea, convergence = run_optimization(
#       2     dike_model=model,
#       3     nfe=200,
#       4     epsilons=epsilon_pf3,
#       5     convergence_metrics=convergence_metrics
#       6 )
#
# Cell In[27], line 8, in run_optimization(dike_model, nfe, epsilons, convergence_metrics)
#       5 print(f"Starting optimization with {nfe} evaluations...")
#       7 with MultiprocessingEvaluator(dike_model) as evaluator:
# ----> 8     results, convergence = evaluator.optimize(
#       9         nfe=nfe,
#      10         searchover="levers",
#      11         epsilons=epsilons,
#      12         convergence=convergence_metrics
#      13     )
#      15 print(f"Optimization completed.")
#      16 return results, convergence
#
# File ~/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/evaluators.py:228, in BaseEvaluator.optimize(self, algorithm, nfe, searchover, reference, constraints, convergence_freq, logging_freq, variator, **kwargs)
#     210 def optimize(
#     211     self,
#     212     algorithm=EpsNSGAII,
#    (...)    220     **kwargs,
#     221 ):
#     222     """convenience method for outcome optimization.
#     223
#     224     is forwarded to :func:optimize, with evaluator and models
#     225     arguments added in.
#     226
#     227     """
# --> 228     return optimize(
#     229         self._msis,
#     230         algorithm=algorithm,
#     231         nfe=int(nfe),
#     232         searchover=searchover,
#     233         evaluator=self,
#     234         reference=reference,
#     235         constraints=constraints,
#     236         convergence_freq=convergence_freq,
#     237         logging_freq=logging_freq,
#     238         variator=variator,
#     239         **kwargs,
#     240     )
#
# File ~/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/evaluators.py:576, in optimize(models, algorithm, nfe, searchover, evaluator, reference, convergence, constraints, convergence_freq, logging_freq, variator, **kwargs)
#     573 if not evaluator:
#     574     evaluator = SequentialEvaluator(models)
# --> 576 return _optimize(
#     577     problem,
#     578     evaluator,
#     579     algorithm,
#     580     convergence,
#     581     nfe,
#     582     convergence_freq,
#     583     logging_freq,
#     584     variator=variator,
#     585     **kwargs,
#     586 )
#
# File ~/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/optimization.py:1101, in _optimize(problem, evaluator, algorithm, convergence, nfe, convergence_freq, logging_freq, variator, **kwargs)
#    1098 evaluator.callback = callback
#    1100 with temporary_filter(name=[callbacks.__name__, evaluators.__name__], level=INFO):
# -> 1101     optimizer.run(nfe)
#    1103 convergence(optimizer, force=True)
#    1105 # convergence.pbar.__exit__(None, None, None)
#
# File ~/decision_making_assignments/venv/lib/python3.13/site-packages/platypus/core.py:741, in Algorithm.run(self, condition, callback)
#     738 for extension in self._extensions:
#     739     extension.pre_step(self)
# --> 741 self.step()
#     743 for extension in self._extensions:
#     744     extension.post_step(self)
#
# File ~/decision_making_assignments/venv/lib/python3.13/site-packages/platypus/algorithms.py:304, in NSGAII.step(self)
#     302 def step(self):
#     303     if self.nfe == 0:
# --> 304         self.initialize()
#     305     else:
#     306         self.iterate()
#
# File ~/decision_making_assignments/venv/lib/python3.13/site-packages/platypus/algorithms.py:314, in NSGAII.initialize(self)
#     313 def initialize(self):
# --> 314     super().initialize()
#     316     if self.archive is not None:
#     317         self.archive += self.population
#
# File ~/decision_making_assignments/venv/lib/python3.13/site-packages/platypus/algorithms.py:106, in AbstractGeneticAlgorithm.initialize(self)
#     104 """Initializes the algorithm."""
#     105 self.population = [self.generator.generate(self.problem) for _ in range(self.population_size)]
# --> 106 self.evaluate_all(self.population)
#
# File ~/decision_making_assignments/venv/lib/python3.13/site-packages/platypus/core.py:702, in Algorithm.evaluate_all(self, solutions)
#     699 unevaluated = [s for s in solutions if not s.evaluated]
#     701 jobs = [EvaluateSolution(s) for s in unevaluated]
# --> 702 results = self.evaluator.evaluate_all(jobs)
#     704 # if needed, update the original solution with the results
#     705 for i, result in enumerate(results):
#
# File ~/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/evaluators.py:153, in BaseEvaluator.evaluate_all(self, jobs, **kwargs)
#     150     raise NotImplementedError()
#     152 # overwrite the default 10 progress reports  with 5 reports
# --> 153 callback = perform_experiments(
#     154     self._msis,
#     155     evaluator=self,
#     156     reporting_frequency=self.reporting_frequency,
#     157     scenarios=scenarios,
#     158     policies=policies,
#     159     return_callback=True,
#     160     log_progress=True,
#     161 )
#     163 experiments, outcomes = callback.get_results()
#     165 if searchover in ("levers", "uncertainties"):
#
# File ~/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/evaluators.py:406, in perform_experiments(models, scenarios, policies, evaluator, reporting_interval, reporting_frequency, uncertainty_union, lever_union, outcome_union, uncertainty_sampling, lever_sampling, callback, return_callback, combine, log_progress, **kwargs)
#     403 if not evaluator:
#     404     evaluator = SequentialEvaluator(models)
# --> 406 evaluator.evaluate_experiments(scenarios, policies, callback, combine=combine, **kwargs)
#     408 if callback.i != nr_of_exp:
#     409     raise EMAError(
#     410         f"Some fatal error has occurred while running the experiments, not all runs have completed. Expected {nr_of_exp}, got {callback.i}"
#     411     )
#
# File ~/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/futures_multiprocessing.py:319, in MultiprocessingEvaluator.evaluate_experiments(self, scenarios, policies, callback, combine)
#     317 def evaluate_experiments(self, scenarios, policies, callback, combine="factorial"):
#     318     ex_gen = experiment_generator(scenarios, self._msis, policies, combine=combine)
# --> 319     add_tasks(self.n_processes, self._pool, ex_gen, callback)
#
# File ~/decision_making_assignments/venv/lib/python3.13/site-packages/ema_workbench/em_framework/futures_multiprocessing.py:224, in add_tasks(n_processes, pool, experiments, callback)
#     221 feeder.start()
#     222 reader.start()
# --> 224 feeder.join()
#     225 results_queue.put(None)
#     226 reader.join()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/threading.py:1092, in Thread.join(self, timeout)
#    1089 if timeout is not None:
#    1090     timeout = max(timeout, 0)
# -> 1092 self._handle.join(timeout)
#
# KeyboardInterrupt:
